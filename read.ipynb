# %%
import pyarrow as pa
import pandas as pd
from pathlib import Path




def transformLaps(year,place,quali):
  caminho2 = Path.cwd() /"silver"/"Data_Laps" /f"year={year}" /f"place={place}" /f"quali={quali}"
  arquivo2 = caminho2 / f'dados_voltas_silver_{place}_{year}.parquet'
  df2 = pd.read_parquet(arquivo2,engine ='fastparquet')
  

  
  return df2
 

transformLaps(2025,'monaco','Q')
# Out:
#              Tempo Piloto Numero_Piloto  Tempo_Volta  Numero_Volta  Stint  \
# 0    1218989000000    NOR             4      107.078           1.0    1.0
# 1    1291849000000    NOR             4       72.860           2.0    1.0
# 2    1391019000000    NOR             4       99.170           3.0    1.0
# 3    1462615000000    NOR             4       71.596           4.0    1.0
# 4    1556516000000    NOR             4       93.901           5.0    1.0
# ..             ...    ...           ...          ...           ...    ...
# 428  1732555000000    COL            43      104.643           8.0    2.0
# 429  1805370000000    COL            43       72.815           9.0    2.0
# 430  1901736000000    COL            43       96.366          10.0    2.0
# 431  1974333000000    COL            43       72.597          11.0    2.0
# 432  2079534000000    COL            43          NaN          12.0    2.0
#
#      Tempo_Saida_Pit  Tempo_Entrada_Pit  Tempo_Setor_1  Tempo_Setor_2  ...  \
# ...
