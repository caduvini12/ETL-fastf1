# %%
import pyarrow as pa
import pandas as pd
from pathlib import Path




def transformLaps(year,place,quali):
  caminho2 = Path.cwd() / "bronze" / "Data_Laps" /f"year={year}" /f"place={place}" /f"quali={quali}"
  arquivo2 = caminho2 / f'dados_voltas_{place}_{year}.parquet'
  df2 = pd.read_parquet(arquivo2,engine ='fastparquet')
  return df2
 

transformLaps(2025,'monaco','Q')
# Out:
#            Time Driver DriverNumber      LapTime  LapNumber  Stint  \
# 0    1218989000    NOR            4  107078000.0        1.0    1.0
# 1    1291849000    NOR            4   72860000.0        2.0    1.0
# 2    1391019000    NOR            4   99170000.0        3.0    1.0
# 3    1462615000    NOR            4   71596000.0        4.0    1.0
# 4    1556516000    NOR            4   93901000.0        5.0    1.0
# ..          ...    ...          ...          ...        ...    ...
# 427  1732555000    COL           43  104643000.0        8.0    2.0
# 428  1805370000    COL           43   72815000.0        9.0    2.0
# 429  1901736000    COL           43   96366000.0       10.0    2.0
# 430  1974333000    COL           43   72597000.0       11.0    2.0
# 431  2079534000    COL           43          NaN       12.0    2.0
#
#        PitOutTime     PitInTime  Sector1Time  Sector2Time  ...  FreshTyre  \
# 0    1.112730e+09           NaN   26421000.0   47431000.0  ...       True
# 1             NaN           NaN   19256000.0   34544000.0  ...       True
# 2             NaN           NaN   25163000.0   47396000.0  ...       True
# 3             NaN           NaN   18806000.0   33840000.0  ...       True
# 4             NaN           NaN   25155000.0   46054000.0  ...       True
# ..            ...           ...          ...          ...  ...        ...
# 427  1.629545e+09           NaN   38776000.0   38634000.0  ...       True
# 428           NaN           NaN   18824000.0   34803000.0  ...       True
# 429           NaN           NaN   26370000.0   44941000.0  ...       True
# 430           NaN           NaN   18756000.0   34535000.0  ...       True
# 431           NaN  2.079534e+09   30083000.0   51967000.0  ...       True
#
#         Team  LapStartTime                LapStartDate  TrackStatus  Position  \
# 0    McLaren    1112730000  2025-05-24 14:03:33.851000            1       NaN
# 1    McLaren    1218989000  2025-05-24 14:05:20.110000            1       NaN
# 2    McLaren    1291849000  2025-05-24 14:06:32.970000            1       NaN
# 3    McLaren    1391019000  2025-05-24 14:08:12.140000            1       NaN
# 4    McLaren    1462615000  2025-05-24 14:09:23.736000            1       NaN
# ..       ...           ...                         ...          ...       ...
# 427   Alpine    1627912000  2025-05-24 14:12:09.033000            1       NaN
# 428   Alpine    1732555000  2025-05-24 14:13:53.676000            1       NaN
# 429   Alpine    1805370000  2025-05-24 14:15:06.491000            1       NaN
# 430   Alpine    1901736000  2025-05-24 14:16:42.857000            1       NaN
# 431   Alpine    1974333000  2025-05-24 14:17:55.454000          125       NaN
#
#      Deleted  DeletedReason  FastF1Generated IsAccurate
# 0      False                           False      False
# 1      False                           False       True
# 2      False                           False       True
# 3      False                           False       True
# 4      False                           False       True
# ..       ...            ...              ...        ...
# 427    False                           False      False
# 428    False                           False       True
# 429    False                           False       True
# 430    False                           False       True
# 431    False                           False      False
#
# [432 rows x 31 columns]
