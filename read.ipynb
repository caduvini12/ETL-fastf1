# %%
import pyarrow as pa
import pandas as pd
from pathlib import Path




def transformLaps(year,place,quali):
  caminho2 = Path.cwd() / "gold" /f"year={year}" /f"place={place}" /f"quali={quali}"
  arquivo2 = caminho2 / f'dados_gold_{place}_{year}.parquet'
  df2 = pd.read_parquet(arquivo2,engine ='fastparquet')
  
  return df2
 

transformLaps(2025,'monaco','Q')
# Out:
#     Piloto  Numero_Volta  Velocidade       Tempo Numero_Piloto  Tempo_Volta  \
# 0      ALB           2.0      276.00  1076869000            23        0.082
# 1      ALB           3.0      287.00  1150022000            23        0.073
# 2      ALB           4.0      279.00  1248344000            23        0.098
# 3      ALB           5.0      286.00  1321133000            23        0.073
# 4      ALB           6.0      275.61  1425215000            23        0.104
# ..     ...           ...         ...         ...           ...          ...
# 247    VER           8.0      288.00  1979401000             1        0.071
# 248    VER          11.0      286.00  2903140000             1        0.071
# 249    VER          14.0      288.00  4026788000             1        0.071
# 250    VER          17.0      288.00  4974285000             1        0.071
# 251    VER          20.0      291.00  5388009000             1        0.071
#
# ...
