# %%
import pyarrow as pa
import pandas as pd
from pathlib import Path




def transformLaps(year,place,quali):
  caminho2 = Path.cwd() / "silver" / "telemetry" /f"year={year}" /f"place={place}" /f"quali={quali}"
  arquivo2 = caminho2 / f'dados_silver_{place}_{year}.parquet'
  df2 = pd.read_parquet(arquivo2,engine ='fastparquet')
  
  return df2
 

transformLaps(2025,'monaco','Q')
# Out:
#                           Data DriverAhead  DistanceToDriverAhead     RPM  \
# 0      2025-05-24 14:03:33.851                         106.278333  4780.6
# 1      2025-05-24 14:03:33.961                         106.278333  4834.0
# 2      2025-05-24 14:03:34.047                         106.278333  4911.1
# 3      2025-05-24 14:03:34.241          27             106.278333  5085.0
# 4      2025-05-24 14:03:34.467          27             111.991114  5329.1
# ...                        ...         ...                    ...     ...
# 476067 2025-05-24 14:19:40.208           5            2215.348331  5446.4
# 476068 2025-05-24 14:19:40.323           5            2219.085833  5399.0
# 476069 2025-05-24 14:19:40.468           5            2223.717777  5455.3
# 476070 2025-05-24 14:19:40.524           5            2225.506667  5477.0
# 476071 2025-05-24 14:19:40.655           5            2225.506667  5709.9
#
#         Velocidade  Marcha  Acelerador  Freio  DRS         Source  Distancia  \
# ...
